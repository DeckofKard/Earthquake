# %%
import folium
import json


city_data = {'종로구' : 0.20,
             '중구' : 0.20,
             '용산구' : 0.20,
             '성동구' : 0.20,
             '광진구' : 0.20,
             '동대문구' : 0.20,
             '중랑구' : 0.20,
             '성북구' : 0.20,
             '강북구' : 0.20,
             '도봉구' : 0.20,
             '노원구' : 0.20,
             '은평구' : 0.20,
             '서대문구' : 0.20,
             '마포구' : 0.20,
             '양천구' : 0.20,
             '강서구' : 0.20,
             '구로구' : 0.20,
             '금천구' : 0.20,
             '영등포구' : 0.20,
             '동작구' : 0.20,
             '관악구' : 0.20,
             '서초구' : 0.20,
             '강남구' : 0.20,
             '송파구' : 0.20,
             '강동구' : 0.20,
             '중구' : 0.12,
             '서구': 0.12,
             '동구' : 0.12,
             '영도구' : 0.12,
             '부산진구' : 0.12,
             '동래구' : 0.12,
             '남구' : 0.12,
             '북구' : 0.12,
             '해운대구' : 0.12,
             '사하구' : 0.12,
             '금정구' : 0.12,
             '강서구' : 0.12,
             '연제구' : 0.12,
             '수영구' : 0.12,
             '사상구' : 0.12,
             '기장군' : 0.12,
             '중구' : 0.155,
             '동구' : 0.155,
             '서구' : 0.155,
             '남구' : 0.155,
             '북구' : 0.155,
             '수성구' : 0.155,
             '달서구' : 0.155,
             '달성군' : 0.155,
             '중구' : 0.201,
              '동구' : 0.201,
             '미추홀구' : 0.201,
             '연수구' : 0.201,
             '남동구' : 0.201,
             '부평구' : 0.201,
             '계양구' : 0.201,
             '서구' : 0.201, 
             '강화군' : 0.201,
             '옹진군' : 0.201,
             ' 동구' : 0.183,
             ' 서구' : 0.183,
             '남구' : 0.183,
             ' 북구' : 0.183,
             '광산구' : 0.183,
             '대구시 동구' : 0.196,
             '대구시 중구' : 0.196,
             '대구시 서구' : 0.196,
             '유성구' : 0.196,
             '대덕구' : 0.196,
             '중구' : 0.214,
             '남구' : 0.214,
             ' 동구' : 0.214,
             ' 북구' : 0.214,
             '울주군' : 0.214,
             '세종특별자치시' : 0.228,
             
             '수원시 장안구' : 0.247,
             '수원시 권선구' : 0.247,
             '수원시 팔달구' : 0.247,
             '수원시 영통구' : 0.247,
             '고양시 덕양구' : 0.247,
             '고양시 일산동구' : 0.247,
             '고양시 일산서구' : 0.247,
             '용인시 처인구' : 0.247,
             '용인시 기흥구' : 0.247,
             '용인시 수지구' : 0.247,
             '성남시 수정구' : 0.247,
             '성남시 중원구' : 0.247,
             '성남시 분당구' : 0.247,
             '부천시' : 0.247,
             '화성시' : 0.247,
             '안산시 상록구' : 0.247,
             '안산시 단원구': 0.247,
             '남양주시' : 0.247,
             
             '안양시 만안구' : 0.247,
             '안양시 동안구' : 0.247,
             '평택시' : 0.247,
             '시흥시' : 0.247,
             '파주시': 0.247,
             '의정부시' : 0.247,
             '김포시' : 0.247,
             '광주시' : 0.247,
             '광명시' : 0.247,
             '군포시' : 0.247,
             '하남시' : 0.247,
             '오산시' : 0.247,
             '양주시' : 0.247,
             '이천시' : 0.247,
             '구리시' : 0.247,
             '안성시' : 0.247,
             '포천시' : 0.247,
             '의왕시' : 0.247,
             '양평군' : 0.247,
             '여주시' : 0.247,
             '동두천시' : 0.247,
             '가평군' : 0.247,
             '과천시' : 0.247,
             '연천군': 0.247,
             '춘천시' : 0.124,
             '원주시' : 0.124,
             '강릉시' : 0.124,
             '동해시' : 0.124,
             '태백시' : 0.124,
             '속초시' : 0.124,
             '삼척시' : 0.124,
             '홍천군' : 0.124,
             '횡성군' : 0.124,
             '영월군' : 0.124,
             '평창군' : 0.124,
             '정선군' : 0.124,
             '철원군' : 0.124,
             '화천군' : 0.124,
             '양구군' : 0.124,
             '인제군' : 0.124,
             '고성군' : 0.124,
             '양양군' : 0.124,
             '청주시 상당구' : 0.124,
             '청주시 서원구' : 0.124,
             '청주시 흥덕구' : 0.124,
             '청주시 청원구' : 0.124,
             '충주시' : 0.142,
             '제천시' : 0.142,
             '보은군' : 0.142,
             '옥천군' : 0.142,
             '영동군' : 0.142,
             '증평군' : 0.142,
             '진천군': 0.142,
             '괴산군' : 0.142,
             '음성군' : 0.142,
             '단양군' : 0.142,
             '천안시 동남구' : 0.144,
             '천안시 서북구' : 0.144,
             '공주시' : 0.144,
             '보령시' : 0.144,
             '아산시' : 0.144, 
             '서산시' : 0.144,
             '논산시' : 0.144,
             '계룡시' : 0.144,
             '당진시' : 0.144,
             '금산군' : 0.144,
             '부여군' : 0.144,
             '서천군' : 0.144,
             '청양군' : 0.144,
             '홍성군' : 0.144,
             '예산군' : 0.144,
             '태안군' : 0.144,
              '전주시 완산구' : 0.133,
              '전주시 덕진구' : 0.133,
             '군산시' : 0.133,
             '익산시' : 0.133,
             '정읍시' : 0.133,
             '남원시' : 0.133,
             '김제시' : 0.133,
             '완주군' : 0.133,
             '진안군' : 0.133,
             '무주군' : 0.133,
             '장수군' : 0.133,
             '임실군' : 0.133,
             '순창군' : 0.133,
             '고창군' : 0.133,
             '부안군' : 0.133,
             '목포시' : 0.121,
             '여수시' : 0.121, 
             '순천시' : 0.121,
             '나주시' : 0.121,
             '광양시' : 0.121,
             '담양군' : 0.121,
             '곡성군' : 0.121,
             '구례군' : 0.121,
             '고흥군' : 0.121,
             '보성군' : 0.121,
             '화순군' : 0.121,
             '장흥군' : 0.121,
             '강진군' : 0.121,
             '해남군' : 0.121,
             '영암군' : 0.121,
             '무안군' : 0.121,
             '함평군' : 0.121,
             '영광군' : 0.121,
             '장성군' : 0.121,
             '완도군' : 0.121,
             '진도군' : 0.121,
             '신안군' : 0.121,
             '포항시 남구' : 0.113,
             '포항시 북구' : 0.113,
             '경주시' : 0.113,
             '김천시' : 0.113,
             '안동시' : 0.113,
             '구미시' : 0.113,
             '영주시' : 0.113,
             '영천시' : 0.113,
             '상주시' : 0.113,
             '문경시' : 0.113,
             '경산시' : 0.113,
             '군위군' : 0.113,
             '의성군' : 0.113,
             '청송군' : 0.113, 
             '영양군' : 0.113,
             '영덕군' : 0.113,
             '청도군' : 0.113,
             '고령군' : 0.113,
             '성주군' : 0.113,
             '칠곡군' : 0.113,
             '예천군' : 0.113,
             '봉화군' : 0.113,
             '울진군' : 0.113,
             '울릉군': 0.113,
             '창원시 의창구' : 0.113,
             '창원시 성산구' : 0.113,
             '창원시 마산합포구' : 0.113,
             '창원시 마산회원구' : 0.113,
             '창원시 진해구' : 0.113,
             '진주시' : 0.121,
             '통영시' : 0.121,
             '사천시' : 0.121,
             '김해시' : 0.121,
             '밀양시' : 0.121,
             '거제시' : 0.121,
             '양산시' : 0.121,
             '의령군' : 0.121,
             '함안군' : 0.121,
             '창녕군' : 0.121,
             '고성군' : 0.121,
             '남해군' : 0.121,
             '하동군' : 0.121,
             '산청군' : 0.121,
             '함양군' : 0.121,
             '거창군' : 0.121,
             '합천군' : 0.121,
             '제주시' : 0.174,
             '서귀포시' :  0.174
            }

# %%
geojson_file = "C:/Users/dbdlf/Korea3.json"

# %%
with open(geojson_file, 'r', encoding='utf-8') as f:
    geojson_data = json.load(f)

# %%
geojson_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.012, 37.582],
#       [127.009, 37.58],
#       [127.007, 37.584],
#       [127.007, 37.585],
#       [127.007, 37.586],
#       [127.004, 37.588],
#       [127.003, 37.588],
#       [127.003, 37.589],
#       [127.002, 37.589],
#       [127.002, 37.59],
#       [127.001, 37.59],
#       [127.001, 37.591],
#       [127.002, 37.591],
#       [127.001, 37.592],
#       [127, 37.592],
#       [126.999, 37.592],
#       [126.998, 37.592],
#       [126.997, 37.592],
#       [126.996, 37.592],
#       [126.995, 37.592],
#       [126.994, 37.592],
#       [126.989, 37.592],
#       [126.988, 37.592],
#       [126.987, 37.593],
#       [126.986, 37.593],
#       [126.986, 37.594],
#       [126.985, 37.594],
#       [126.984, 37.594],
#       [126.983, 37.595],
#       [126.982, 37.595],
#       [126.981, 37.595],
#       [126.981, 37.596],
# ...

# %%
center = [36.5, 127.5]

# %%
folium
map = folium.Map(location=center, zoom_start=7)

# %%
all_provinces = []  # 모든 지역을 저장하기 위한 리스트

for feature in geojson_data['features']:
    properties = feature['properties']
    province = properties["SIG_KOR_NM"]
    all_provinces.append(province)  # 모든 지역을 리스트에 추가



    if province in city_data:
        rate = city_data[province]
        color ='blue'
        
        
        if rate <= 0.1:
            color = 'red'
        elif rate <= 0.15:
            color = 'orange'
        elif rate <= 0.2:
             color = 'yellow'
       
        folium.GeoJson(
            feature,
            style_function=lambda x, color=color: {
                'fillColor': color,
                'color': 'black',
                'weight': 1,
                'fillOpacity': 0.7
            }
        ).add_to(map)

# %%
# 모든 지역 출력
for province in all_provinces :
    print(province)
# Out:
# 종로구
# 중구
# 용산구
# 성동구
# 광진구
# 동대문구
# 중랑구
# 성북구
# 강북구
# 도봉구
# 노원구
# 은평구
# 서대문구
# 마포구
# 양천구
# 강서구
# 구로구
# 금천구
# 영등포구
# 동작구
# 관악구
# 서초구
# 강남구
# 송파구
# 강동구
# 중구
# 서구
# 동구
# 영도구
# 부산진구
# 동래구
# 남구
# 북구
# 해운대구
# 사하구
# 금정구
# 강서구
# 연제구
# 수영구
# 사상구
# 기장군
# 중구
# 동구
# 서구
# 남구
# 북구
# 수성구
# 달서구
# 달성군
# 중구
# 동구
# 미추홀구
# 연수구
# 남동구
# 부평구
# 계양구
# 서구
# 강화군
# 옹진군
# 동구
# 서구
# 남구
# 북구
# 광산구
# 동구
# 중구
# 서구
# 유성구
# 대덕구
# 중구
# 남구
# 동구
# 북구
# 울주군
# 세종특별자치시
# 수원시 장안구
# 수원시 권선구
# 수원시 팔달구
# 수원시 영통구
# 성남시 수정구
# 성남시 중원구
# 성남시 분당구
# 의정부시
# 안양시 만안구
# 안양시 동안구
# 부천시
# 광명시
# 평택시
# 동두천시
# 안산시 상록구
# 안산시 단원구
# 고양시 덕양구
# 고양시 일산동구
# 고양시 일산서구
# 과천시
# 구리시
# 남양주시
# 오산시
# 시흥시
# 군포시
# 의왕시
# 하남시
# 용인시 처인구
# 용인시 기흥구
# 용인시 수지구
# 파주시
# 이천시
# 안성시
# 김포시
# 화성시
# 광주시
# 양주시
# 포천시
# 여주시
# 연천군
# 가평군
# 양평군
# 춘천시
# 원주시
# 강릉시
# 동해시
# 태백시
# 속초시
# 삼척시
# 홍천군
# 횡성군
# 영월군
# 평창군
# 정선군
# 철원군
# 화천군
# 양구군
# 인제군
# 고성군
# 양양군
# 청주시 상당구
# 청주시 서원구
# 청주시 흥덕구
# 청주시 청원구
# 충주시
# 제천시
# 보은군
# 옥천군
# 영동군
# 증평군
# 진천군
# 괴산군
# 음성군
# 단양군
# 천안시 동남구
# 천안시 서북구
# 공주시
# 보령시
# ...

# %%
# 지도를 HTML 파일로 저장

map.save('earthquake_map.html')

# %%
for feature in geojson_data['features']:
    properties = feature['properties']
    province = properties['SIG_KOR_NM']
 
    # 내진율 데이터가 있는 경우에만 색상 설정
    if province in city_data:
        rate = city_data[province] 
        color = 'blue'
        print(1)
        
        if rate <= 0.1:
            color = 'red'
            print(2)
        elif rate <= 0.15:
            color = 'orange'
            print(3)
        elif rate <= 0.2:
            color = 'yellow'
            print(4)
        else:
            color = 'green'
            print(5)

        folium.GeoJson(
            feature,
            style_function=lambda x: {
                'fillColor': color,
                'color': 'black',
                'weight': 1,
                'fillOpacity': 0.7
            }
        ).add_to(map)
# Out:
# 1
# 4
# 1
# 5
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 3
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 3
# 1
# 3
# 1
# 3
# 1
# 5
# 1
# 4
# 1
# 3
# 1
# 3
# 1
# 3
# 1
# 3
# 1
# 3
# 1
# 3
# 1
# 3
# 1
# 3
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 4
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 4
# 1
# 4
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 4
# 1
# 4
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 4
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 5
# 1
# 3
# 1
# 3
# 1
# 3
# 1
# 3
# 1
# 3
# 1
# 3
# 1
# 3
# 1
# 3
# ...

# %%
for province in all_provinces :
    print(province)
# Out:
# 종로구
# 중구
# 용산구
# 성동구
# 광진구
# 동대문구
# 중랑구
# 성북구
# 강북구
# 도봉구
# 노원구
# 은평구
# 서대문구
# 마포구
# 양천구
# 강서구
# 구로구
# 금천구
# 영등포구
# 동작구
# 관악구
# 서초구
# 강남구
# 송파구
# 강동구
# 중구
# 서구
# 동구
# 영도구
# 부산진구
# 동래구
# 남구
# 북구
# 해운대구
# 사하구
# 금정구
# 강서구
# 연제구
# 수영구
# 사상구
# 기장군
# 중구
# 동구
# 서구
# 남구
# 북구
# 수성구
# 달서구
# 달성군
# 중구
# 동구
# 미추홀구
# 연수구
# 남동구
# 부평구
# 계양구
# 서구
# 강화군
# 옹진군
# 동구
# 서구
# 남구
# 북구
# 광산구
# 동구
# 중구
# 서구
# 유성구
# 대덕구
# 중구
# 남구
# 동구
# 북구
# 울주군
# 세종특별자치시
# 수원시 장안구
# 수원시 권선구
# 수원시 팔달구
# 수원시 영통구
# 성남시 수정구
# 성남시 중원구
# 성남시 분당구
# 의정부시
# 안양시 만안구
# 안양시 동안구
# 부천시
# 광명시
# 평택시
# 동두천시
# 안산시 상록구
# 안산시 단원구
# 고양시 덕양구
# 고양시 일산동구
# 고양시 일산서구
# 과천시
# 구리시
# 남양주시
# 오산시
# 시흥시
# 군포시
# 의왕시
# 하남시
# 용인시 처인구
# 용인시 기흥구
# 용인시 수지구
# 파주시
# 이천시
# 안성시
# 김포시
# 화성시
# 광주시
# 양주시
# 포천시
# 여주시
# 연천군
# 가평군
# 양평군
# 춘천시
# 원주시
# 강릉시
# 동해시
# 태백시
# 속초시
# 삼척시
# 홍천군
# 횡성군
# 영월군
# 평창군
# 정선군
# 철원군
# 화천군
# 양구군
# 인제군
# 고성군
# 양양군
# 청주시 상당구
# 청주시 서원구
# 청주시 흥덕구
# 청주시 청원구
# 충주시
# 제천시
# 보은군
# 옥천군
# 영동군
# 증평군
# 진천군
# 괴산군
# 음성군
# 단양군
# 천안시 동남구
# 천안시 서북구
# 공주시
# 보령시
# ...

# %%
print(rate)
# Out:
# 0.174
